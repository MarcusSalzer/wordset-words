# %% [markdown]
# # Look at the words
#
# We load all the words from the dictionary and count them

# %%
import json
import os
from glob import glob

import numpy as np
import pandas as pd
from plotly import express as px
from plotly import graph_objects as go

# %% [markdown]
# ## Load data

# %%
filenames = glob(os.path.join("data", "*.json"))

words_all = {}
for name in filenames:
    with open(name, "r") as f:
        words_all.update(json.load(f))

words_df = pd.DataFrame.from_dict(words_all, orient="index")
print("# entries:", len(words_df))
# Out:
# # entries: 108133

# %%
display(words_df.head(10))
# Out:
#                             word  wordset_id  \
# a cappella            a cappella  5feb6f679a
# AD                            AD  76c6ebfae9
# A.D.                        A.D.  b7e9d406a0
# anno Domini          anno Domini  69164a0c91
# ahorse                    ahorse  125f8f20e1
# ahorseback            ahorseback  795c5656e2
# anisotropically  anisotropically  9e676e43af
# annoyingly            annoyingly  5088c7d529
# about                      about  0b26c47336
# all right              all right  46249e29ca
#
#                                                           meanings  \
# a cappella       [{'id': '492099d426', 'def': 'without musical ...
# AD               [{'id': '4c21c72afa', 'def': 'in the Christian...
# A.D.             [{'id': 'a7482f3e30', 'def': 'in the Christian...
# anno Domini      [{'id': 'b7bebf59dd', 'def': 'in the Christian...
# ahorse           [{'id': 'b6428adf79', 'def': 'on the back of a...
# ahorseback       [{'id': '164d08dc8d', 'def': 'on the back of a...
# anisotropically  [{'id': 'da4d5a2b10', 'def': 'in an anisotropi...
# annoyingly       [{'id': '4f73c0859f', 'def': 'in an annoying m...
# about            [{'id': 'c8c0ac13b0', 'def': 'imprecise quanti...
# all right        [{'id': 'b5e43f1411', 'def': 'in a satisfactor...
#
#                        editors                      contributors labels
# a cappella                 NaN                               NaN    NaN
# AD                         NaN                               NaN    NaN
# A.D.                       NaN                               NaN    NaN
# anno Domini                NaN                               NaN    NaN
# ahorse                     NaN                               NaN    NaN
# ahorseback                 NaN                               NaN    NaN
# anisotropically            NaN                               NaN    NaN
# annoyingly                 NaN                               NaN    NaN
# about            [zellerpress]  [sabreuse, lauradhahn, lefurjah]    NaN
# all right                  NaN                               NaN    NaN

# %%
meanings_all = []
words_per_meaning = []
for mean_list, word in zip(words_df.meanings.items(), words_df.index):
    # if there is a list of "meaning"-dicts
    if isinstance(mean_list[1], list):
        for meaning in mean_list[1]:
            meanings_all.append(meaning)
            words_per_meaning.append(word)

meanings_df = pd.DataFrame.from_records(meanings_all)
meanings_df = meanings_df.assign(word=words_per_meaning)

display(meanings_df.head())
# Out:
#            id                                      def  \
# 0  492099d426            without musical accompaniment
# 1  0bf8d49e2e  sung without instrumental accompaniment
# 2  4c21c72afa                     in the Christian era
# 3  a7482f3e30                     in the Christian era
# 4  b7bebf59dd                     in the Christian era
#
#                         example speech_part             synonyms labels  \
# 0     they performed a cappella      adverb                  NaN    NaN
# 1  they sang an a cappella Mass   adjective                  NaN    NaN
# 2                           NaN      adverb  [A.D., anno Domini]    NaN
# 3                           NaN      adverb                 [AD]    NaN
# 4                           NaN      adverb                 [AD]    NaN
#
#   -example         word
# 0      NaN   a cappella
# 1      NaN   a cappella
# 2      NaN           AD
# 3      NaN         A.D.
# 4      NaN  anno Domini

# %%
## dict of possible POS for each word

speech_parts = meanings_df.groupby("word")["speech_part"].apply(set).apply(tuple)
speech_parts = pd.DataFrame(speech_parts)

# count possible PoS per word:
speech_parts = speech_parts.assign(pos_count=speech_parts["speech_part"].apply(len))

# %%
speech_parts.loc[speech_parts.pos_count == 3].head(10)
# Out:
#                            speech_part  pos_count
# word
# French         (verb, adjective, noun)          3
# O.K.              (verb, noun, adverb)          3
# a la carte   (adjective, noun, adverb)          3
# above        (adjective, noun, adverb)          3
# abstract       (verb, adjective, noun)          3
# accelerando  (adjective, noun, adverb)          3
# ace            (verb, adjective, noun)          3
# ad-lib         (verb, adjective, noun)          3
# adagio       (adjective, noun, adverb)          3
# advance        (verb, adjective, noun)          3

# %%
speech_parts_singles = speech_parts.loc[speech_parts["pos_count"] == 1]
speech_parts_singles = speech_parts_singles.assign(
    speech_part=[x[0] for x in speech_parts_singles["speech_part"]]
)
print("# entries with :", len(speech_parts))
print("# entries with unique PoS:", len(speech_parts_singles))
# Out:
# # entries with : 108128
# # entries with unique PoS: 101286

# %%
px.histogram(speech_parts_singles, x="speech_part", template="plotly_dark")

# %%
speech_parts[speech_parts["speech_part"].apply(lambda t: "pronoun" in t)]
# Out:
#              speech_part  pos_count
# word
# he       (pronoun, noun)          2
# her           (pronoun,)          1
# hers          (pronoun,)          1
# herself       (pronoun,)          1
# him           (pronoun,)          1
# himself       (pronoun,)          1
# his           (pronoun,)          1
# she           (pronoun,)          1
# they          (pronoun,)          1
# we       (verb, pronoun)          2
# y'all         (pronoun,)          1
# yall          (pronoun,)          1

# %%
words_df.loc[words_df["word"] == "i"]
# Out:
#   word  wordset_id                                           meanings editors  \
# i    i  3de5a03e19  [{'id': '11cba2a877', 'def': 'used of a single...     NaN
#
#   contributors labels
# i          NaN    NaN

# %%
unique_pos_combis = speech_parts.speech_part.unique()
for x in unique_pos_combis:
    print(x)
# Out:
# ('noun',)
# ('adjective',)
# ('adverb',)
# ('adjective', 'noun')
# ('verb',)
# ('phrase',)
# ('verb', 'adjective', 'noun')
# ('verb', 'adjective')
# ('verb', 'noun')
# ('verb', 'noun', 'adverb')
# ('noun', 'adverb')
# ('noun', 'article')
# ('adjective', 'adverb')
# ('adjective', 'noun', 'adverb')
# ('interjection',)
# ('preposition',)
# ('verb', 'adjective', 'noun', 'adverb')
# ('verb', 'adjective', 'adverb')
# ('verb', 'adverb')
# ('pronoun', 'noun')
# ('pronoun',)
# ('verb', 'interjection', 'noun')
# ('phrase', 'adverb')
# ('verb', 'pronoun')
# ('preposition', 'adverb')
